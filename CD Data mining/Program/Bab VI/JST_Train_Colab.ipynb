# %%
#Impor Pustaka
# %tensorflow_version 1.x
import tensorflow
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.models import model_from_yaml
from google.colab import files
import io

upload_files = files.upload()
for filename in upload_files.keys():
  x=upload_files[filename].decode('utf-8')
data1 = pd.read_csv(io.StringIO(x), header=None)
print(data1.head())

upload_files = files.upload()
for filename in upload_files.keys():
  x=upload_files[filename].decode('utf-8')
data2 = pd.read_csv(io.StringIO(x), header=None)
print(data2.head())

upload_files = files.upload()
for filename in upload_files.keys():
  x=upload_files[filename].decode('utf-8')
data3 = pd.read_csv(io.StringIO(x), header=None)
print(data3.head())

#data training
df1=pd.DataFrame(data1,columns=['Mahasiswa','IPK','Tingkat Kemiskinan (TM)','Beasiswa/Tidak'])
X1=np.asarray(data1)
x_train=X1[1:,1:3]
y_train=X1[1:,3:4]
#data validasi
df2=pd.DataFrame(data2,columns=['Mahasiswa','IPK','Tingkat Kemiskinan (TM)','Beasiswa/Tidak'])
X2=np.asarray(data2)
x_val=X2[1:,1:3]
y_val=X2[1:,3:4]
#data testing
df3=pd.DataFrame(data3,columns=['Mahasiswa','IPK','Tingkat Kemiskinan (TM)','Beasiswa/Tidak'])
X3=np.asarray(data3)
x_test=X3[1:,1:3]
y_test=X3[1:,3:4]

#Mendifinisiakan arsitektur model
model = Sequential()
model.add(Dense(64, input_dim=2,activation = "relu")) #Layer 1 (NOTE: sesuaikan dimensi input)
model.add(Dense(32,activation = "relu")) #Layer 2
model.add(Dense(32,activation = "relu")) #Layer 3
model.add(Dense(8,activation = "relu")) #Layer 4
model.add(Dense(8,activation = "relu")) #Layer 5
model.add(Dense(4,activation = "relu")) #Layer 6
model.add(Dense(1,activation = "sigmoid")) #Output Layer

#Mengkonfigurasi Model
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])
#Train the model
model.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_val,y_val))
#Prediksi hasil simulasi model JST terhadap data validasi
pred = model.predict(x_val)
print(pred)

from keras.models import model_from_yaml
# serialize model to YAML
model_yaml = model.to_yaml()
with open("model.yaml", "w") as yaml_file:
    yaml_file.write(model_yaml)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
files.download("model.yaml")
files.download("model.h5")
# Out:
# TensorFlow 1.x selected.
# Using TensorFlow backend.
#      <input type="file" id="files-94ae91b0-b5eb-4872-b598-da4b1623998a" name="files[]" multiple disabled />
#      <output id="result-94ae91b0-b5eb-4872-b598-da4b1623998a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving beasiswa.csv to beasiswa.csv
#            0     1                        2               3
# 0  Mahasiswa   IPK  Tingkat Kemiskinan (TM)  Beasiswa/Tidak
# 1          1  0.80                     0.80            0.00
# 2          2  1.20                     1.00            0.00
# 3          3  1.00                     1.20            0.00
# 4          4  2.00                     1.50            0.00
#      <input type="file" id="files-1b9ac5ec-c365-4e88-8634-1edbd3f78576" name="files[]" multiple disabled />
#      <output id="result-1b9ac5ec-c365-4e88-8634-1edbd3f78576">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving validasibeasiswa.csv to validasibeasiswa.csv
#            0    1                        2                 3
# 0  Mahasiswa  IPK  Tingkat Kemiskinan (TM)  Beasiswa/Tidak *
# 1          1  0.7                      0.7                 0
# 2          2  1.2                      1.1                 0
# 3          3  0.6                      1.6                 0
# 4          4  2.4                      3.1                 1
#      <input type="file" id="files-486d1eab-b875-4833-842c-b8d19fd30af8" name="files[]" multiple disabled />
#      <output id="result-486d1eab-b875-4833-842c-b8d19fd30af8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving testbeasiswa.csv to testbeasiswa.csv
#            0     1                        2                 3
# 0  Mahasiswa   IPK  Tingkat Kemiskinan (TM)  Beasiswa/Tidak *
# 1          1  0.75                     0.74                 0
# 2          2  1.25                     1.16                 0
# 3          3  0.67                     1.69                 0
# 4          4  2.47                     3.19                 1
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 11 samples, validate on 7 samples
# Epoch 1/100
# 11/11 [==============================] - 0s 41ms/step - loss: 0.7052 - accuracy: 0.4545 - val_loss: 0.7033 - val_accuracy: 0.4286
# Epoch 2/100
# 11/11 [==============================] - 0s 516us/step - loss: 0.7009 - accuracy: 0.4545 - val_loss: 0.6960 - val_accuracy: 0.2857
# Epoch 3/100
# 11/11 [==============================] - 0s 337us/step - loss: 0.6951 - accuracy: 0.3636 - val_loss: 0.6880 - val_accuracy: 0.7143
# Epoch 4/100
# 11/11 [==============================] - 0s 343us/step - loss: 0.6888 - accuracy: 0.6364 - val_loss: 0.6836 - val_accuracy: 0.5714
# Epoch 5/100
# 11/11 [==============================] - 0s 316us/step - loss: 0.6858 - accuracy: 0.5455 - val_loss: 0.6836 - val_accuracy: 0.5714
# Epoch 6/100
# 11/11 [==============================] - 0s 334us/step - loss: 0.6860 - accuracy: 0.5455 - val_loss: 0.6838 - val_accuracy: 0.5714
# Epoch 7/100
# 11/11 [==============================] - 0s 367us/step - loss: 0.6860 - accuracy: 0.5455 - val_loss: 0.6837 - val_accuracy: 0.5714
# Epoch 8/100
# 11/11 [==============================] - 0s 442us/step - loss: 0.6859 - accuracy: 0.5455 - val_loss: 0.6834 - val_accuracy: 0.5714
# Epoch 9/100
# 11/11 [==============================] - 0s 500us/step - loss: 0.6854 - accuracy: 0.5455 - val_loss: 0.6827 - val_accuracy: 0.5714
# Epoch 10/100
# 11/11 [==============================] - 0s 443us/step - loss: 0.6848 - accuracy: 0.5455 - val_loss: 0.6820 - val_accuracy: 0.5714
# Epoch 11/100
# 11/11 [==============================] - 0s 417us/step - loss: 0.6842 - accuracy: 0.5455 - val_loss: 0.6812 - val_accuracy: 0.5714
# Epoch 12/100
# 11/11 [==============================] - 0s 310us/step - loss: 0.6834 - accuracy: 0.5455 - val_loss: 0.6805 - val_accuracy: 0.5714
# Epoch 13/100
# 11/11 [==============================] - 0s 332us/step - loss: 0.6827 - accuracy: 0.5455 - val_loss: 0.6796 - val_accuracy: 0.5714
# Epoch 14/100
# 11/11 [==============================] - 0s 357us/step - loss: 0.6819 - accuracy: 0.5455 - val_loss: 0.6786 - val_accuracy: 0.5714
# Epoch 15/100
# 11/11 [==============================] - 0s 353us/step - loss: 0.6810 - accuracy: 0.5455 - val_loss: 0.6775 - val_accuracy: 0.5714
# Epoch 16/100
# 11/11 [==============================] - 0s 353us/step - loss: 0.6801 - accuracy: 0.5455 - val_loss: 0.6764 - val_accuracy: 0.5714
# Epoch 17/100
# 11/11 [==============================] - 0s 369us/step - loss: 0.6791 - accuracy: 0.5455 - val_loss: 0.6753 - val_accuracy: 0.5714
# Epoch 18/100
# 11/11 [==============================] - 0s 570us/step - loss: 0.6781 - accuracy: 0.5455 - val_loss: 0.6741 - val_accuracy: 0.5714
# Epoch 19/100
# 11/11 [==============================] - 0s 380us/step - loss: 0.6770 - accuracy: 0.5455 - val_loss: 0.6727 - val_accuracy: 0.5714
# 11/11 [==============================] - 0s 523us/step - loss: 0.4536 - accuracy: 0.7273 - val_loss: 0.3963 - val_accuracy: 0.8571
# Epoch 82/100
# 11/11 [==============================] - 0s 541us/step - loss: 0.4482 - accuracy: 0.8182 - val_loss: 0.3903 - val_accuracy: 0.8571
# Epoch 83/100
# 11/11 [==============================] - 0s 390us/step - loss: 0.4427 - accuracy: 0.9091 - val_loss: 0.3840 - val_accuracy: 0.8571
# Epoch 84/100
# 11/11 [==============================] - 0s 765us/step - loss: 0.4369 - accuracy: 0.9091 - val_loss: 0.3776 - val_accuracy: 0.8571
# Epoch 85/100
# 11/11 [==============================] - 0s 365us/step - loss: 0.4309 - accuracy: 0.9091 - val_loss: 0.3709 - val_accuracy: 1.0000
# Epoch 86/100
# 11/11 [==============================] - 0s 442us/step - loss: 0.4247 - accuracy: 0.9091 - val_loss: 0.3642 - val_accuracy: 1.0000
# Epoch 87/100
# 11/11 [==============================] - 0s 565us/step - loss: 0.4183 - accuracy: 0.9091 - val_loss: 0.3574 - val_accuracy: 1.0000
# Epoch 88/100
# 11/11 [==============================] - 0s 553us/step - loss: 0.4117 - accuracy: 0.9091 - val_loss: 0.3508 - val_accuracy: 1.0000
# Epoch 89/100
# 11/11 [==============================] - 0s 552us/step - loss: 0.4051 - accuracy: 0.9091 - val_loss: 0.3440 - val_accuracy: 1.0000
# Epoch 90/100
# 11/11 [==============================] - 0s 555us/step - loss: 0.3984 - accuracy: 0.9091 - val_loss: 0.3368 - val_accuracy: 1.0000
# Epoch 91/100
# 11/11 [==============================] - 0s 811us/step - loss: 0.3914 - accuracy: 0.9091 - val_loss: 0.3292 - val_accuracy: 1.0000
# Epoch 92/100
# 11/11 [==============================] - 0s 843us/step - loss: 0.3842 - accuracy: 0.9091 - val_loss: 0.3217 - val_accuracy: 1.0000
# Epoch 93/100
# 11/11 [==============================] - 0s 740us/step - loss: 0.3768 - accuracy: 0.9091 - val_loss: 0.3141 - val_accuracy: 1.0000
# Epoch 94/100
# 11/11 [==============================] - 0s 481us/step - loss: 0.3692 - accuracy: 0.9091 - val_loss: 0.3059 - val_accuracy: 1.0000
# Epoch 95/100
# 11/11 [==============================] - 0s 553us/step - loss: 0.3614 - accuracy: 0.9091 - val_loss: 0.2975 - val_accuracy: 1.0000
# Epoch 96/100
# 11/11 [==============================] - 0s 501us/step - loss: 0.3533 - accuracy: 0.9091 - val_loss: 0.2900 - val_accuracy: 1.0000
# Epoch 97/100
# 11/11 [==============================] - 0s 652us/step - loss: 0.3449 - accuracy: 0.9091 - val_loss: 0.2826 - val_accuracy: 1.0000
# Epoch 98/100
# 11/11 [==============================] - 0s 578us/step - loss: 0.3364 - accuracy: 0.9091 - val_loss: 0.2742 - val_accuracy: 1.0000
# Epoch 99/100
# 11/11 [==============================] - 0s 629us/step - loss: 0.3276 - accuracy: 0.9091 - val_loss: 0.2659 - val_accuracy: 1.0000
# Epoch 100/100
# 11/11 [==============================] - 0s 495us/step - loss: 0.3187 - accuracy: 0.9091 - val_loss: 0.2579 - val_accuracy: 1.0000
# [[0.29651156]
#  [0.37569517]
#  [0.31985074]
#  [0.8276074 ]
#  [0.8280388 ]
#  [0.9241809 ]
#  [0.869375  ]]
# Saved model to disk
